# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook
sns.set()

# %% [markdown]
# Отримання збережених даних

# %%
# %store -r results

# %% [markdown]
# Побудова відповідних візуалізацій

# %%
fig, ax = plt.subplots()
plt.bar(results[0].city_state.tolist(), results[0].customers_count.tolist())
plt.yticks([0, 1, 2])
plt.xlabel('State')
plt.ylabel('Customers count')
plt.title("Кількість покупців в кожному з шаттів");
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
plt.title('Частка прибутку кожного товару')
plt.pie(results[1].total_sum.tolist(), labels=results[1].sku.tolist(), autopct='%1.1f%%');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
plt.title("Співвідношення кількості та відповідної ціни, для товару MEFREL59AC079AE6C6F-L")
plt.xlabel('Quantity ordered')
plt.ylabel('Total')
plt.plot(results[2].qty_ordered.tolist(), results[2].total.tolist(), marker='o');
# Out:
# <img src="data:image/png;base64,..." width="640">
